# %% [markdown]
# # Log 01-03-2023
# ## Observations
# ### 16:53 init
#
# - what are the functions of Docker in this repo?
#     - https://www.youtube.com/watch?v=bi0cKgmRuiA
# - how to utilize the Makefile?
# - setup.py?
#     - https://www.youtube.com/watch?v=JKegib9jgVA

# %% [markdown]
# ### 18:45
#
# [resolved] Cannot handle pure integer index

# %% [markdown]
# ### 21:17
#
# Cannot identify:
# - [resolved] option
# - [resolved] $ONTEXT, $OFFTEXT
# - loop
# - if
# - `p(i) = -1 ;`
#     - caused by the minus sign...

# %% [markdown]
# ## Code Playground

# %%
from gams2pyomo import GamsParser

f = 'test/gams_big/test.gms'

# f = 'test/gams/misc/display.gms'
# f = 'test/gams/assignment/suffix.gms'
# f = 'test/gams/flow_control/abort.gms'
# f = 'test/gams/flow_control/loop.gms'
# f = 'test/gams/flow_control/if-else.gms'
# f = 'test/gams/flow_control/if-single.gms'
# f = 'test/gams/flow_control/if-elseif-else.gms'

gp = GamsParser(f)
parse_tree=gp.parse()
print(parse_tree.pretty())
# Out:
# start
#   option_setting
#     option_name	LIMROW
#     option_value	0
#   option_setting
#     option_name	LIMCOL
#     option_value	0
#   option_setting
#     option_name	OPTCA
#     option_value	1E-09
#   option_setting
#     option_name	OPTCR
#     option_value	1E-03
#   option_setting
#     option_name	RESLIM
#     option_value	1E+04
#   option_setting
#     option_name	ITERLIM
#     option_value	1E+09
#   option_setting
#     option_name	LP
#     option_value	CPLEX
#   option_setting
#     option_name	NLP
#     option_value	SNOPT
#   option_setting
#     option_name	MIP
#     option_value	CPLEX
#   option_setting
#     option_name	MINLP
#     option_value	SCIP
#   set_list
#     definition
#       symbol
#         symbol_name	S
#     definition
#       symbol
#         symbol_name	p
#       description	"products"
#       data
#         symbol_range
#           1
#           3
#     definition
#       symbol
#         symbol_name	n
#       description	"event points"
# ...
